# %%
print(__doc__)

# Author: Phil Roth <mr.phil.roth@gmail.com>
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.figure(figsize=(12, 12))

n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, random_state=random_state)

# Incorrect number of clusters
y_pred = KMeans(n_clusters=2, random_state=random_state).fit_predict(X)

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Incorrect Number of Blobs")

plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X)

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Potentially correct Number of Blobs")

plt.show()

# %%
y_pred = KMeans(n_clusters=5, random_state=random_state).fit_predict(X)

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Incorrect Number of Blobs")

plt.show()

# %%
y_pred = KMeans(n_clusters=7, random_state=random_state).fit_predict(X)

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Incorrect Number of Blobs")

plt.show()

# %%
y_pred = KMeans(n_clusters=9, random_state=random_state).fit_predict(X)

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Incorrect Number of Blobs")

plt.show()

# %% [markdown]
# ### Plotting inertia to n_clusters for Elbow curve

# %%
listOfInertia = []
clusters = []
for index in range(1,13):
    kModel = KMeans(n_clusters=index, random_state=random_state).fit(X)
    listOfInertia.append(kModel.inertia_)
    clusters.append(index)

# %%
plt.plot(clusters,listOfInertia)

# %%
# Yes, the elbow appears to be in-line with what I expect it to be. The plots seemed to indicate that there were 3 natural
# clusters and this elbow tapers off at around 3 clusters.

# %%
from yellowbrick.cluster import InterclusterDistance

k3Model = kModel = KMeans(n_clusters=3, random_state=random_state)

visualizer = InterclusterDistance(k3Model)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# C:\Users\Do-While\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
